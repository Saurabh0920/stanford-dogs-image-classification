# %% [markdown]
# # 4) VGG16 - Feature Extraction + Augmentation
#
# **Purpose:** Combine feature extraction with data augmentation to improve robustness.

# %%
# Use ImageDataGenerator (or tf.data) with preprocessing for VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
# Example: train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input, rotation_range=20, horizontal_flip=True)
